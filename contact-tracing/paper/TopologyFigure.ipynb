# %% [markdown]
# This notebook exists to generate a figure for the paper.

# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import pandas as pd
import random
import seaborn as sns
import statistics

# %%
import sys

sys.path.append('../code/Python')

import model

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 7))

wsg = nx.watts_strogatz_graph(400, 4, 0.1)

nx.draw_circular(
    wsg,
    node_size = 15,
    ax = axes[0]
)

N, M = (20, 20)

g = model.grid_r(N,M, 0.1)


## draw_spectral for the lattice
nx.draw(
    g,
    pos = model.grid_pos(g),
    node_size = 15,
    ax = axes[1]
)

fig.tight_layout()
plt.savefig('fig_topologies.pdf', format='pdf')
